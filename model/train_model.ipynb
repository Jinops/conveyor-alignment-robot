# %% [markdown]
# ref: https://colab.research.google.com/drive/16nRwsioEYqWFLBF5VpT_NvELeOeupURM

# %% [markdown]
# My environment:
# - Python v3.10
# - cuda toolkit v11.8
# - cuda driver v12.2

# %%
# !python -V
print()
# !nvcc --version
print()
# !nvidia-smi
# Out:
# Python 3.10.3
#
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
#
# Sat Dec  2 19:38:09 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.23                 Driver Version: 536.23       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060      WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   37C    P8              14W / 170W |    658MiB / 12288MiB |     15%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      3348    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      6324    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A      8488    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     10472    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10736    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     10832    C+G   ...oogle\Chrome\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     11008    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     12948    C+G   ..._8wekyb3d8bbwe\HxCalendarAppImm.exe    N/A      |
# |    0   N/A  N/A     14100    C+G   ...Programs\Microsoft VS Code\Code.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Set home directory

# %%
home='D:/Code/conveyor-alignment-robot/yolov5_obb'
# %cd {home}

# %% [markdown]
# (Optional) Set terminal language to English

# %%
# !chcp 437
# Out:
# Active code page: 437

# %%
# !pip install torch==1.12.0+cu113 torchvision==0.13.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Requirement already satisfied: torch==1.12.0+cu113 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (1.12.0+cu113)
# Requirement already satisfied: torchvision==0.13.0+cu113 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (0.13.0+cu113)
# Requirement already satisfied: typing-extensions in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from torch==1.12.0+cu113) (4.8.0)
# Requirement already satisfied: numpy in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from torchvision==0.13.0+cu113) (1.26.2)
# Requirement already satisfied: requests in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from torchvision==0.13.0+cu113) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from torchvision==0.13.0+cu113) (10.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests->torchvision==0.13.0+cu113) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests->torchvision==0.13.0+cu113) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests->torchvision==0.13.0+cu113) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests->torchvision==0.13.0+cu113) (2023.7.22)

# %%
# !git clone https://github.com/jinops/yolov5_obb
#git clone https://github.com/hukaixuan19970627/yolov5_obb
# Out:
# fatal: destination path 'yolov5_obb' already exists and is not an empty directory.

# %%
# !pip install -r requirements.txt
# Out:
# D:\Code\conveyor-alignment-robot\yolov5_obb
# Requirement already satisfied: matplotlib>=3.2.2 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 4)) (3.8.2)
# Requirement already satisfied: numpy>=1.18.5 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 5)) (1.26.2)
# Requirement already satisfied: opencv-python>=4.5.4 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 6)) (4.8.1.78)
# Requirement already satisfied: Pillow>=7.1.2 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 7)) (10.1.0)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 9)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 10)) (1.11.4)
# Requirement already satisfied: torch>=1.7.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 11)) (1.12.0+cu113)
# Requirement already satisfied: torchvision>=0.8.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 12)) (0.13.0+cu113)
# Requirement already satisfied: tqdm>=4.41.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 13)) (4.66.1)
# Requirement already satisfied: tensorboard>=2.4.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 16)) (2.15.1)
# Requirement already satisfied: pandas>=1.1.4 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 20)) (2.1.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 21)) (0.13.0)
# Requirement already satisfied: thop in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from -r requirements.txt (line 37)) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2023.7.22)
# Requirement already satisfied: typing-extensions in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (4.8.0)
# Requirement already satisfied: colorama in c:\users\jinwo\appdata\roaming\python\python310\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.23.4)
# Requirement already satisfied: setuptools>=41.0.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (68.0.0)
# Requirement already satisfied: six>1.9 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.0.1)
# Requirement already satisfied: pytz>=2020.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2023.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.2.2)

# %%
# %cd {home}/utils/nms_rotated
# !pip install -v -e .
# Out:
# D:\Code\conveyor-alignment-robot\yolov5_obb\utils\nms_rotated
# Using pip 23.3.1 from D:\Programs\anaconda3\envs\yolo_obb\lib\site-packages\pip (python 3.10)
# Obtaining file:///D:/Code/conveyor-alignment-robot/yolov5_obb/utils/nms_rotated
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Running command python setup.py egg_info
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "D:\Code\conveyor-alignment-robot\yolov5_obb\utils\nms_rotated\setup.py", line 5, in <module>
#       import torch
#     File "D:\Programs\anaconda3\envs\yolo_obb\lib\site-packages\torch\__init__.py", line 140, in <module>
#       raise err
#   OSError: [WinError 126] 지정된 모듈을 찾을 수 없습니다. Error loading "D:\Programs\anaconda3\envs\yolo_obb\lib\site-packages\torch\lib\torch_python.dll" or one of its dependencies.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   full command: 'D:\Programs\anaconda3\envs\yolo_obb\python.exe' -c '
#   exec(compile('"'"''"'"''"'"'
#   # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#   #
#   # - It imports setuptools before invoking setup.py, to enable projects that directly
#   #   import from `distutils.core` to work with newer packaging standards.
#   # - It provides a clear error message when setuptools is not installed.
#   # - It sets `sys.argv[0]` to the underlying `setup.py`, when invoking `setup.py` so
#   #   setuptools doesn'"'"'t think the script is `-c`. This avoids the following warning:
#   #     manifest_maker: standard file '"'"'-c'"'"' not found".
#   # - It generates a shim setup.py, for handling setup.cfg-only projects.
#   import os, sys, tokenize
#
#   try:
#       import setuptools
#   except ImportError as error:
#       print(
#           "ERROR: Can not execute `setup.py` since setuptools is not available in "
#           "the build environment.",
#           file=sys.stderr,
#       )
#       sys.exit(1)
#
#   __file__ = %r
#   sys.argv[0] = __file__
#
#   if os.path.exists(__file__):
#       filename = __file__
#       with tokenize.open(__file__) as f:
#           setup_py_code = f.read()
#   else:
#       filename = "<auto-generated setuptools caller>"
#       setup_py_code = "from setuptools import setup; setup()"
#
#   exec(compile(setup_py_code, filename, "exec"))
#   '"'"''"'"''"'"' % ('"'"'D:\\Code\\conveyor-alignment-robot\\yolov5_obb\\utils\\nms_rotated\\setup.py'"'"',), "<pip-setuptools-caller>", "exec"))' egg_info --egg-base 'C:\Users\jinwo\AppData\Local\Temp\pip-pip-egg-info-9jm2ykzm'
#   cwd: D:\Code\conveyor-alignment-robot\yolov5_obb\utils\nms_rotated\
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# Dataset download.
#
# (After download proejct, you have to <b>change folder name to roboflow</b>)

# %%
# %cd {home}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QZHOlVku6ydKvynKH3qs")
project = rf.workspace("project-nfco4").project("airport_baggage")
dataset = project.version(1).download("yolov5-obb")
# Out:
# D:\Code\conveyor-alignment-robot\yolov5_obb\datasets
# Requirement already satisfied: roboflow in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (1.1.11)
# Requirement already satisfied: certifi==2023.7.22 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (3.8.2)
# Requirement already satisfied: numpy>=1.18.5 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (1.26.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (10.1.0)
# Requirement already satisfied: pyparsing==2.4.7 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: supervision in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (0.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (2.1.0)
# Requirement already satisfied: tqdm>=4.41.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: colorama in c:\users\jinwo\appdata\roaming\python\python310\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib->roboflow) (4.45.1)
# Requirement already satisfied: packaging>=20.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in d:\programs\anaconda3\envs\yolo_obb\lib\site-packages (from supervision->roboflow) (1.11.4)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Code\conveyor-alignment-robot\train_model.ipynb Cell 13 line 5
#       <a href='vscode-notebook-cell:/d%3A/Code/conveyor-alignment-robot/train_model.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_line_magic('cd', '{home}/datasets')
#       <a href='vscode-notebook-cell:/d%3A/Code/conveyor-alignment-robot/train_model.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> get_ipython().system('pip install roboflow')
# ----> <a href='vscode-notebook-cell:/d%3A/Code/conveyor-alignment-robot/train_model.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> from roboflow import Roboflow
#       <a href='vscode-notebook-cell:/d%3A/Code/conveyor-alignment-robot/train_model.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> rf = Roboflow(api_key="QZHOlVku6ydKvynKH3qs")
#       <a href='vscode-notebook-cell:/d%3A/Code/conveyor-alignment-robot/train_model.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> project = rf.workspace("project-nfco4").project("airport_baggage")
#
# File d:\Programs\anaconda3\envs\yolo_obb\lib\site-packages\roboflow\__init__.py:11
#       8 import requests
#      10 from roboflow.config import API_URL, APP_URL, DEMO_KEYS, load_roboflow_api_key
# ---> 11 from roboflow.core.project import Project
#      12 from roboflow.core.workspace import Workspace
#      13 from roboflow.models import CLIPModel, GazeModel
#
# File d:\Programs\anaconda3\envs\yolo_obb\lib\site-packages\roboflow\core\project.py:8
#       5 import warnings
#       7 import requests
# ----> 8 from PIL import Image, UnidentifiedImageError
#      10 from roboflow.adapters import rfapi
#      11 from roboflow.config import API_URL, DEFAULT_BATCH_NAME, DEMO_KEYS
#
# File d:\Programs\anaconda3\envs\yolo_obb\lib\site-packages\PIL\Image.py:82
#      73 MAX_IMAGE_PIXELS = int(1024 * 1024 * 1024 // 4 // 3)
#      76 try:
#      77     # If the _imaging C module is not present, Pillow will not load.
#      78     # Note that other modules should not refer to _imaging directly;
#      79     # import Image and use the Image.core variable instead.
#      80     # Also note that Image.core is not a publicly documented interface,
#      81     # and should be considered private and subject to change.
# ---> 82     from . import _imaging as core
#      84     if __version__ != getattr(core, "PILLOW_VERSION", None):
#      85         msg = (
#      86             "The _imaging extension was built for another version of Pillow or PIL:\n"
#      87             f"Core version: {getattr(core, 'PILLOW_VERSION', None)}\n"
#      88             f"Pillow version: {__version__}"
#      89         )
#
# ImportError: cannot import name '_imaging' from 'PIL' (d:\Programs\anaconda3\envs\yolo_obb\lib\site-packages\PIL\__init__.py)

# %% [markdown]
# Train

# %%
# %cd {home}/yolov5_obb/
# !python train.py --data {home}/datasets/roboflow/data.yaml --epochs 3 --batch-size 1 --img 640 --device 0 --exist-ok
# Out:
# D:\Code\conveyor-alignment-robot\yolov5_obb
# github: up to date with https://github.com/jinops/yolov5_obb
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# train: weights=weights\yolov5n.pt, cfg=, data=D:/Code/conveyor-alignment-robot/datasets/roboflow/data.yaml, hyp=data\hyps\obb\hyp.finetune_dota.yaml, epochs=3, batch_size=1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=True, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  3e5fc33 torch 1.12.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
#
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, theta=0.5, theta_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=180.0, translate=0.1, scale=0.25, shear=0.0, perspective=0.0, flipud=0.5, fliplr=0.5, mosaic=0.75, mixup=0.1, copy_paste=0.0, cls_theta=180, csl_radius=2.0
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=26
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1    285483  models.yolo.Detect                      [26, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model Summary: 270 layers, 2042635 parameters, 2042635 gradients, 5.1 GFLOPs
#
# Transferred 343/349 items from weights\yolov5n.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight, 60 weight (no decay), 60 bias
jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# ...
# train: WARNING: ..\datasets\roboflow\train\images\Z20_jpg.rf.dad0d3c38115c02771c6ec9a371a6c1a.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z23_jpg.rf.04df54bbba5346e2d8e4d8feec890515.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z23_jpg.rf.3dcc2f79b5d4b59ef79ca92fee9924f4.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z23_jpg.rf.436c10d22c96297aefc004045642559f.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z24_jpg.rf.010eedec7b562cd18a3f0d97dd7c870d.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z24_jpg.rf.51d03e84898198bb20883d105ba03e9a.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z24_jpg.rf.6b360aaf0f7b24c7f53e5c543cf64f53.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z25_jpg.rf.07e2eeb3c0bce387737dfa9fbf5693f1.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z25_jpg.rf.719d3a6106f38f322b81f14d1c175cc7.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z25_jpg.rf.a1ce0a89405facf72fdde0ec0af82b13.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z26_jpg.rf.3a0a0031fa269e6d38edeab38f0e8569.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z26_jpg.rf.afa30b227dac65ec8851bd0273c2909a.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z26_jpg.rf.eda897f17a461a3eb1987fe65ae884a0.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z27_jpg.rf.05bb90ed83c1371baef2500a22967be4.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z27_jpg.rf.41a2b70840fd8dd000fb159bf4cbd1c4.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z27_jpg.rf.f3fd0da906c0ac5291ca5e09232b42a5.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z4_jpg.rf.6a4977c313395b07441a3b19f4234f02.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z4_jpg.rf.b7acd6d64b3d82832549aebbb8949a00.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z4_jpg.rf.f5595bd45ff1b76262e092a6686d3a87.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z6_jpg.rf.0fca78e9ef8eb51e33d73a737e280f4a.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z6_jpg.rf.2267c3cb709f37fc5242f937c401a767.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z6_jpg.rf.a897aa4bab018a9a9485e7f24cda75f0.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z7_jpg.rf.0a1d6cb911dc210602205aa5cc51cbab.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z7_jpg.rf.1fa3bb48c652bf438064e0340b285434.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z7_jpg.rf.5638466c29d50438a763d58733b352b7.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z8_jpg.rf.26e76bb3f413f77bd3153ace3e6d68a7.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z8_jpg.rf.666d6ba8474f478db214008a9b4a184d.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z8_jpg.rf.c99a1389f6752ec1c8ba8d6049345e39.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z9_jpg.rf.5df6781b072b98c33a37ed4595346957.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z9_jpg.rf.df599ec44342564112f0f4e7292c4468.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# train: WARNING: ..\datasets\roboflow\train\images\Z9_jpg.rf.feabc0d09aec565b7d4980db7d93cc23.jpg: ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)
# Traceback (most recent call last):
#   File "D:\Code\conveyor-alignment-robot\yolov5_obb\train.py", line 633, in <module>
#     main(opt)
#   File "D:\Code\conveyor-alignment-robot\yolov5_obb\train.py", line 530, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "D:\Code\conveyor-alignment-robot\yolov5_obb\train.py", line 213, in train
#     train_loader, dataset = create_dataloader(train_path, imgsz, batch_size // WORLD_SIZE, gs, names, single_cls,
#   File "D:\Code\conveyor-alignment-robot\yolov5_obb\utils\datasets.py", line 101, in create_dataloader
#     dataset = LoadImagesAndLabels(path, names, imgsz, batch_size,
#   File "D:\Code\conveyor-alignment-robot\yolov5_obb\utils\datasets.py", line 444, in __init__
#     labels, shapes, self.segments = zip(*cache.values())
# ValueError: not enough values to unpack (expected 3, got 0)

# %% [markdown]
# > If you have a error `ignoring corrupt image/label: The DType <class 'numpy._IntegerAbstractDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy._IntegerAbstractDType'>, <class 'numpy.dtypes.StrDType'>)`, then `conda update --all`
